# %% [markdown]
# <img src="https://imgs.search.brave.com/nAN7oz_7Lp8wj8rE-mskHnfOvhevF5v56ZXkqOwjbKc/rs:fit:500:0:0:0/g:ce/aHR0cHM6Ly9zMy5l/dS13ZXN0LTMuYW1h/em9uYXdzLmNvbS9t/b292aWpvYi5wcm9k/LzI0NjUyOTAvbGdf/Y2VzaS1qYXVuZS5w/bmc" style="height:100px;">
#
# # <center> CER 15
# # <center> Parsing apartments
# # <center> Part 1 </center>
#
# Date : 02/12/24

# %% [markdown]
# # <center> Prosit 1 : Parsing apartments
#
# #### Roles:
# * Facilitator: Oussama
# * Manager: Junior
# * Secretary: Palal
# * Scribe: Peïo
#
# ## 1) Understanding the Topic and Clarifying
# ### 1.1) Keywords:
#
# -	**Dendrogram** :  is a diagrammatic representation of a hierarchical relationship between objects, often created as an output from hierarchical clustering.
#
# -	**K-means cluster Algorithm** : is a popular unsupervised machine learning algorithm for partitioning a dataset into K clusters based on their similarities.
# -	**Intelligent Analysis** : is the application of individual and collective cognitive methods to weigh data and test hypotheses within a secret socio-cultural context.
# -	**Census tract** : a geographic region defined for the purpose of systematic procedure of acquiring, recording, and calculating population information about the members of a given population, usually displayed in the form of statistics.
# -	**Scatter Plot** : is a type of plot or mathematical diagram using Cartesian coordinates to display values for typically two variables for a set of data.
#
# -	**Supervised and Unsupervised learning** : is a type of machine learning where a model is trained on labeled data, meaning the data has been annotated with correct outputs or responses. while, is a type of machine learning where a model is trained on unlabeled data, without any predefined output labels.
#
# -	**Hierarchical ascending classification** : HAC is a type of hierarchical clustering algorithm that performs classification in an ascending manner, starting from a single class and recursively dividing it into finer-grained sub-classes until a desired level of granularity is reached.
# -	**Classification Vs clustering** :  is a supervised learning technique that assigns data points to predefined classes while is an unsupervised learning method that groups data points based on similarities.
#
# ### 1.2) Context:
#
# A Loft’s Craft real estate agency wants to optimize the number or visit by easing on AI tool to divide their estate into 2.
#
# ## 2) Needs Analysis:
# ### 2.1) Issues:
#
# -	How do we prepare the data and apply the k-means algo for clustering?
#
# ### 2.2) Constraints:
#
# -	Data given
# -	Restricted to K-means
#
# ### 2.3) Deliverable:
#
# -	Jupyter Notebook containing processus from preparing data to applying K-means for clustering
#
# ## 3) Generalization:
#
# -	Data pre-processing / wrangling
#
# ## 4) Solution Tracks:
#
# -	Would have to remove column
# -	Median_income would be key
#
# ## 5) Developing the Action Plan:
#
# 1.	Define keywords.
# 2.	Exercise WS.
# 3.	Resource Analysis.
# 4.	Exploration and research K-means, data pre-processing, classification
# 5.	Pre-processing the data (cleaning, etc.)
# 6.	Apply K-means algorithm
# 7.	Graph clustered data
# 8.	Validation of assumptions.
# 9.	Analysis and Conclusion.

# %% [markdown]
# ## Resource analysis

# %% [markdown]
# ### Supervised vs Unsupervised Learning
#
# Supervised and unsupervised learning are two fundamental approaches in machine learning. The primary difference between them lies in the type of data used to train the models.
#
# **Supervised Learning**: In supervised learning, the model is trained on labeled data, where the input data is paired with the desired output. The goal is to learn a mapping between input and output variables, enabling the model to make predictions on new, unseen data.
#
# <img src="https://imgs.search.brave.com/pjDBGCMyKWNkJaPnbxk7-QWbkuqPOc24oyW0AZZTjPo/rs:fit:860:0:0:0/g:...">
#
# #### Key Characteristics of Supervised Learning:
# - Uses labeled data
# * Trained to predict outcomes or classify data
# - Requires human oversight and labeling of data
# * **Examples**: image recognition, speech recognition, sentiment analysis
#
# **Unsupervised Learning**: In unsupervised learning, the model is trained on unlabeled data, and the goal is to discover patterns, relationships, or groupings within the data.
#
# <img src="https://imgs.search.brave.com/XTLY1fdf13quZsgrkrfAs_YSVx_KSsrMVL_xC4pOYn4/rs:fit:860:0:0:0/g:...">
#
#
# #### Key Characteristics of Unsupervised Learning:
# - Uses unlabeled data
# * Trained to discover patterns or relationships
# - Does not require human oversight or labeling of data
# * **Examples**: clustering, dimensionality reduction, anomaly detection

# %% [markdown]
# ### Classification vs Clustering
#
# Classification and clustering are two essential machine learning techniques used for analyzing data. While they share some similarities, there are key differences between the two.
#
# <img src="https://imgs.search.brave.com/O6MknaUbUTsujjqpUULkdEWeKurOsgc48rsXlbgqC4A/rs:fit:860:0:0:0/g:...">
#
# * **Classification**: Classification is a supervised learning technique that assigns data points to predefined classes. It requires a training set with correctly labeled examples to learn patterns that distinguish classes. The objective of classification is to assign data points to known classes, and the output is a model that can predict the class of new data points based on patterns learned from training data.
#   <img src="https://media.geeksforgeeks.org/wp-content/uploads/classification-1.png">
#
# - **Clustering**: Clustering is an unsupervised learning method that groups data points based on similarities. It does not rely on predefined classes and discovers natural groupings in data based on shared characteristics. The objective of clustering is to find meaningful groups and structures in an unlabeled dataset, and the output is the groups themselves along with their profiles.
# <img src="https://imgs.search.brave.com/8NHBGiy3s7LxgeAp3qWXnTnzJ---P6GLpczzmettBT0/rs:fit:500:0:0:0/g:ce/aHR0cHM6Ly91cGxv/YWQud2lraW1lZGlh/Lm9yZy93aWtpcGVk/aWEvY29tbW9ucy90/aHVtYi9iL2I3L1NM/SU5LLUdhdXNzaWFu/LWRhdGEuc3ZnLzUx/MnB4LVNMSU5LLUdh/dXNzaWFuLWRhdGEu/c3ZnLnBuZw">
#
# #### Key differences:
#
# - Predefined Classes: Classification requires predefined classes, while clustering does not rely on predefined classes.
# * Objective: The objective of classification is to assign data points to known classes, while the objective of clustering is to find meaningful groups and structures in an unlabeled dataset.
# - Output: The output of classification is a model that can predict the class of new data points, while the output of clustering is the groups themselves along with their profiles.
#
# #### Examples:
# - Classification: Examples of classification include logistic regression, support vector machines, and decision trees.
# * Clustering: Examples of clustering include the k-means clustering algorithm, hierarchical clustering, and DBSCAN (Density-Based Spatial Clustering of Applications with Noise).

# %% [markdown]
# ## k-means clustering algorithm
#
# The goal of clustering is to divide the population or set of data points into a number of groups so that the data points within each group are more comparable to one another and different from the data points within the other groups.
#
# ### Pseudocode
#
# Initialize k means with random values
#
# --> For a given number of iterations:
#
#     --> Iterate through items:
#
#         --> Find the mean closest to the item by calculating the euclidean distance of the item with each of the means
#
#         --> Assign item to mean
#
#         --> Update mean by shifting it to the average of the items in that cluster

# %% [markdown]
# ## Data Categories
#
# * Nominal: is a type of categorical data where the categories do not have a natural order or ranking. E.g : Colors, etc
# - Ordinal: is a type of categorical data where the categories have a natural ordering or ranking. E.g: A,B,C,D
#
# |Nominal Data|Ordinal Data|
# |---------|-----|
# |Nominal data can’t be quantified, neither they have any intrinsic ordering	|Ordinal data gives some kind of sequential order by their position on the scale|
# |Nominal data is qualitative data or categorical data	|Ordinal data is said to be “in-between” qualitative data and quantitative data|
# |They don’t provide any quantitative value, neither can we perform any arithmetical operation	|They provide sequence and can assign numbers to ordinal data but cannot perform the arithmetical operation|
# |Nominal data cannot be used to compare with one another	|Ordinal data can help to compare one item with another by ranking or ordering|
# |Examples: Eye color, housing style, gender, hair color, religion, marital status, ethnicity, etc	|Examples: Economic status, customer satisfaction, education level, letter grades, etc|

# %% [markdown]
# # Solution
#
# We start by preparing data, cleaning it, clustering and classifying it. Then we have the initial graphs as initially given in the problem which we proceed to pre-process.

# %%
import pandas as pd
import matplotlib.pyplot as plt
from scipy.cluster.hierarchy import dendrogram, linkage

def load_housing_data(): 
 csv_path = "C:/Users/junio/OneDrive/Documents/CESI/A3/IA/IA1/housing.csv"
 return pd.read_csv(csv_path);

# %%
housing = load_housing_data()

# %%
housing.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.23     37.88                41.0        880.0           129.0
# 1    -122.22     37.86                21.0       7099.0          1106.0
# 2    -122.24     37.85                52.0       1467.0           190.0
# 3    -122.25     37.85                52.0       1274.0           235.0
# 4    -122.25     37.85                52.0       1627.0           280.0
#
#    population  households  median_income  median_house_value ocean_proximity
# 0       322.0       126.0         8.3252            452600.0        NEAR BAY
# 1      2401.0      1138.0         8.3014            358500.0        NEAR BAY
# 2       496.0       177.0         7.2574            352100.0        NEAR BAY
# 3       558.0       219.0         5.6431            341300.0        NEAR BAY
# 4       565.0       259.0         3.8462            342200.0        NEAR BAY

# %%
housing.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20640 entries, 0 to 20639
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           20640 non-null  float64
#  1   latitude            20640 non-null  float64
#  2   housing_median_age  20640 non-null  float64
#  3   total_rooms         20640 non-null  float64
#  4   total_bedrooms      20433 non-null  float64
#  5   population          20640 non-null  float64
#  6   households          20640 non-null  float64
#  7   median_income       20640 non-null  float64
#  8   median_house_value  20640 non-null  float64
#  9   ocean_proximity     20640 non-null  object
# dtypes: float64(9), object(1)
# memory usage: 1.6+ MB

# %%
housing.describe()
# Out:
#           longitude      latitude  housing_median_age   total_rooms  \
# count  20640.000000  20640.000000        20640.000000  20640.000000
# mean    -119.569704     35.631861           28.639486   2635.763081
# std        2.003532      2.135952           12.585558   2181.615252
# min     -124.350000     32.540000            1.000000      2.000000
# 25%     -121.800000     33.930000           18.000000   1447.750000
# 50%     -118.490000     34.260000           29.000000   2127.000000
# 75%     -118.010000     37.710000           37.000000   3148.000000
# max     -114.310000     41.950000           52.000000  39320.000000
#
#        total_bedrooms    population    households  median_income  \
# count    20433.000000  20640.000000  20640.000000   20640.000000
# mean       537.870553   1425.476744    499.539680       3.870671
# std        421.385070   1132.462122    382.329753       1.899822
# min          1.000000      3.000000      1.000000       0.499900
# ...

# %%
housing["ocean_proximity"].value_counts()
# Out:
# ocean_proximity
# <1H OCEAN     9136
# INLAND        6551
# NEAR OCEAN    2658
# NEAR BAY      2290
# ISLAND           5
# Name: count, dtype: int64

# %%
housing.hist(bins=50, figsize=(20,15))
# Out:
# array([[<Axes: title={'center': 'longitude'}>,
#         <Axes: title={'center': 'latitude'}>,
#         <Axes: title={'center': 'housing_median_age'}>],
#        [<Axes: title={'center': 'total_rooms'}>,
#         <Axes: title={'center': 'total_bedrooms'}>,
#         <Axes: title={'center': 'population'}>],
#        [<Axes: title={'center': 'households'}>,
#         <Axes: title={'center': 'median_income'}>,
#         <Axes: title={'center': 'median_house_value'}>]], dtype=object)

# %%
from scipy.cluster.hierarchy import dendrogram, linkage 
from sklearn.cluster import AgglomerativeClustering 

X = housing.copy() # A new copy of data set 
X.drop("ocean_proximity", axis=1, inplace=True) # Not numerical 
X.drop("total_bedrooms", axis=1, inplace=True) # Missing values 
X.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  population  \
# 0    -122.23     37.88                41.0        880.0       322.0
# 1    -122.22     37.86                21.0       7099.0      2401.0
# 2    -122.24     37.85                52.0       1467.0       496.0
# 3    -122.25     37.85                52.0       1274.0       558.0
# 4    -122.25     37.85                52.0       1627.0       565.0
#
#    households  median_income  median_house_value
# 0       126.0         8.3252            452600.0
# 1      1138.0         8.3014            358500.0
# 2       177.0         7.2574            352100.0
# 3       219.0         5.6431            341300.0
# 4       259.0         3.8462            342200.0

# %%
plt.figure(figsize=(10, 7)) 
dendrogram(linkage(X, method='ward'), orientation='top', distance_sort='descending', show_leaf_counts=True, ax=None)
plt.show()

# %%
cluster = AgglomerativeClustering(n_clusters=2, metric='euclidean', linkage='ward') 
cluster.fit_predict(X) 
plt.figure(figsize=(10, 7)) 
plt.scatter(X['longitude'],X['latitude'], c=cluster.labels_, cmap='rainbow') 
plt.show()

# %%
sample_incomplete_rows = housing[housing.isnull().any(axis=1)].head() 
sample_incomplete_rows.drop("total_bedrooms", axis=1)
# Out:
#      longitude  latitude  housing_median_age  total_rooms  population  \
# 290    -122.16     37.77                47.0       1256.0       570.0
# 341    -122.17     37.75                38.0        992.0       732.0
# 538    -122.28     37.78                29.0       5154.0      3741.0
# 563    -122.24     37.75                45.0        891.0       384.0
# 696    -122.10     37.69                41.0        746.0       387.0
#
#      households  median_income  median_house_value ocean_proximity
# 290       218.0         4.3750            161900.0        NEAR BAY
# 341       259.0         1.6196             85100.0        NEAR BAY
# 538      1273.0         2.5762            173400.0        NEAR BAY
# 563       146.0         4.9489            247100.0        NEAR BAY
# 696       161.0         3.9063            178400.0        NEAR BAY

# %%
housing.dropna(subset=["total_bedrooms"])
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                41.0        880.0           129.0
# 1        -122.22     37.86                21.0       7099.0          1106.0
# 2        -122.24     37.85                52.0       1467.0           190.0
# 3        -122.25     37.85                52.0       1274.0           235.0
# 4        -122.25     37.85                52.0       1627.0           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                25.0       1665.0           374.0
# 20636    -121.21     39.49                18.0        697.0           150.0
# 20637    -121.22     39.43                17.0       2254.0           485.0
# 20638    -121.32     39.43                18.0       1860.0           409.0
# 20639    -121.24     39.37                16.0       2785.0           616.0
#
# ...

# %%
median = housing["total_bedrooms"].median() 
sample_incomplete_rows.dropna(subset=["total_bedrooms"]) 
sample_incomplete_rows
# Out:
#      longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 290    -122.16     37.77                47.0       1256.0           435.0
# 341    -122.17     37.75                38.0        992.0           435.0
# 538    -122.28     37.78                29.0       5154.0           435.0
# 563    -122.24     37.75                45.0        891.0           435.0
# 696    -122.10     37.69                41.0        746.0           435.0
#
#      population  households  median_income  median_house_value ocean_proximity
# 290       570.0       218.0         4.3750            161900.0        NEAR BAY
# 341       732.0       259.0         1.6196             85100.0        NEAR BAY
# 538      3741.0      1273.0         2.5762            173400.0        NEAR BAY
# 563       384.0       146.0         4.9489            247100.0        NEAR BAY
# 696       387.0       161.0         3.9063            178400.0        NEAR BAY

# %%
from sklearn.impute import SimpleImputer
import numpy as np
imputer = SimpleImputer(strategy="median")

# %%
housing_num = housing.select_dtypes(include=[np.number])

# %%
imputer.fit(housing_num)
# Out:
# SimpleImputer(strategy='median')

# %%
x = imputer.transform(housing_num)

# %%
housing_tr = pd.DataFrame(x, columns=housing_num.columns, index=housing_num.index)

# %% [markdown]
# ## Conclusion
#
# In conclusion, After the data preparation stage. The definition of the choice pipeline to prepare the data so that it as suitable as possible for the execution of the K-Means algorithm.
#
# K-means clustering will be a powerful unsupervised machine learning algorithm for grouping unlabeled datasets as the given ones from the problem. Its objective is to divide data into clusters, making similar data points part of the same group. The algorithm initializes cluster centroids and iteratively assigns data points to the nearest centroid, updating centroids based on the mean of points in each cluster.
